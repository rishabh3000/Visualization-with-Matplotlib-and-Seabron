# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# ### line charts

# %%
yield_apples =[0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples)

# %%
plt.plot(yield_apples);

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
import jovian

# %%
plt.plot(years,yield_apples);

# %% [markdown]
# #### Axis lable

# %%
plt.plot(years,yield_apples)
plt.xlabel("year")
plt.ylabel("yield(tons per hectare)");

# %% [markdown]
# ### plotting multiple line

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel("year")
plt.ylabel("yield( tons in hectare)");

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel("year")
plt.ylabel("yield(tons per hectare)")
plt.title("crop yields in Himachal")
plt.legend(["Apples","Orange"]);

# %% [markdown]
# ### line marker

# %%
plt.plot(years,apples, marker ="o")
plt.plot(years,oranges, marker ="x")
plt.xlabel("year")
plt.ylabel("yield(tons per hectare)")
plt.title("crop yields in Himachal")
plt.legend(["Apples","Orange"]);

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years,oranges, "or")
plt.title("yield of oranges(tons of heactare)");

# %% [markdown]
# ### changing the figure size

# %%
plt.plot(figsize=(12,6))
plt.plot(years,oranges, "or")
plt.title("yield of oranges(tons of heactare)");

# %% [markdown]
# #### fmt = "[marker][line][color]"

# %% [markdown]
# ## Improving Default Style using Seaborn

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(5,5),dpi=200)
plt.plot(years,apples,"s-b")
plt.plot(years,oranges,"o--r")
plt.xlabel("year")
plt.ylabel("yield(tons per hectare)")
plt.title("crop yield in Himachal")
plt.legend(["Apple","Oranges"]);

# %%
sns.set_style("darkgrid")

# %%
plt.plot(years,apples,"s-b")
plt.plot(years,oranges,"o--r")
plt.xlabel("year")
plt.ylabel("yield (tons per hectare)")
plt.title("crop in Himachal")
plt.legend(["Apples","Oranges"]);

# %%
jovian.commit(project='python-matplotlib-data-visualization')
# Out:
# [jovian] Updating notebook "btech15277-18/python-matplotlib-data-visualization" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/btech15277-18/python-matplotlib-data-visualization
# 'https://jovian.ai/btech15277-18/python-matplotlib-data-visualization'

# %% [markdown]
# ### Scatter Plot

# %%
# Load data into a Pandas dataframe
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width,hue=flowers_df.species,s=100);

# %% [markdown]
# ### adding Hue in above plot for postion of the species

# %% [markdown]
# #### customizing Seabron Figure

# %%
plt.figure(figsize=(12,6))
plt.title("sepal Dimensions")

sns.scatterplot(x=flowers_df.sepal_length,
               y=flowers_df.sepal_length,
               hue=flowers_df.species,
               s=100);

# %%
plt.title('Sepal Dimensions')

sns.scatterplot(x='sepal_length', 
                y='sepal_width', 
                hue='species',
                s=100,
                data=flowers_df);

# %% [markdown]
# ## Histogram

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of sepal width")
plt.hist(flowers_df.sepal_width);

# %%
plt.hist(flowers_df.sepal_width,bins=5);

# %%
import numpy as np
np.arange(2,5,0.25)
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
plt.hist(flowers_df.sepal_width,bins=np.arange(2,5,.25));

# %% [markdown]
# ### multiple Histograms

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);
